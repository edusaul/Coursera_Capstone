# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# Loading libraries

# %% [markdown]
# ## First part: Download the data

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np 
import pandas as pd

# %% [markdown]
# Download the Wikipwdia page and find the table with the data

# %%
source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(source, 'lxml')

table = soup.find('table')

# %% [markdown]
# Get the names of the columns from the first row of the table

# %%
headline = table.tbody.tr.text
headline = headline.split('\n')
while('' in headline) :
    headline.remove('') 
print(headline)
# Out:
# ['Postcode', 'Borough', 'Neighbourhood']

# %% [markdown]
# Get all the rows in the table and store in a numpy array, ignoring the "Not assigned" ones

# %%
data_table=np.array(headline)

for element in table.find_all('tr') [1:]:
    columns = element.find_all('td')
    el=[]
    for i, column in enumerate(columns, start=0):
        el.append(column.get_text().strip('\n'))
        #print(i,el)
    #print(el)
    if(el[1] != 'Not assigned') :
        data_table=np.vstack((data_table,el))

# %% [markdown]
# Create a pandas dataframe from the numpy array

# %%
df=pd.DataFrame(data=data_table[1:,0:],
                  columns=data_table[0,0:])
df=df.rename(columns={'Postcode':'Postal Code', 'Neighbourhood':'Neighborhood'})
df.head()
# Out:
#   Postal Code           Borough      Neighborhood
# 0         M3A        North York         Parkwoods
# 1         M4A        North York  Victoria Village
# 2         M5A  Downtown Toronto      Harbourfront
# 3         M5A  Downtown Toronto       Regent Park
# 4         M6A        North York  Lawrence Heights

# %% [markdown]
# Shape of the dataframe

# %%
df.shape
# Out:
# (211, 3)

# %% [markdown]
# ## Second part: geolocalization

# %% [markdown]
# Download the csv file with the geospatial data

# %%
# !wget -O Geospatial_Coordinates.csv https://cocl.us/Geospatial_data/Geospatial_Coordinates.csv
# Out:
# --2019-05-20 19:11:37--  https://cocl.us/Geospatial_data/Geospatial_Coordinates.csv
# Resolving cocl.us (cocl.us)... 169.48.113.201
# Connecting to cocl.us (cocl.us)|169.48.113.201|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-05-20 19:11:37--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.25.197, 107.152.24.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.25.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-05-20 19:11:38--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-05-20 19:11:38--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.27.211, 107.152.26.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.27.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!iMLzFyFqNNkXPQ_ZRIPpkIAbag19pctmEqX8B-ntjHmaM8nN6dxP9zuh53j2YvTu0Rie5l778cUBSYsPIknkfrstG798clQirf4E4JD7DTkJycWFGsjQp17jz0oSSYgaP0ugcbIZxvAvD9RP3liyOyZ8WhXRPWgiN88vXqfaw2OcRrqPbI0gotcJ1JAA17Er3OCo60I55pOmK4ZfIWNLp1lFgNNMC5mcI1dNS2aijIQZ2qAwh7Z-CIA-ClawRkFMin4b8RHoKBMDnfYSOIyOwucCq6IfLfBokOL46a37DnBO3sdetK4EyUVVwTa3QdUkNHFLVSxZGV8IBO3t6GCPPQ2e8DFdvd030W3jgVCBglibJJIzC7i9GtOiLIjFa_ZVU-WpMnIUf5mMzSMyQntUupKZjzfAZnUQLVeCJQzoys0DRfWlxyVlzXMXo-HOf7RGjJcT2zIvJgmR0dI8hxOqE4UBd8dxir9FsXt9et-vN0FxlNWw07MLNYFjn3Vlotb29wsOcFzTGByFgCVgis4RoqvVEXzlKPlVdkzXtVIkMWfBx_46K_OYREvIAR5STwBb1qxW9ZwLhuPlBOuETG4jNODDTrfDekr2IaRv79P_0wJjPo6vUAgO2WX-DoRXBgd7lTqFRjmYFQQ_cLdlFkvMJalLaF1O31BHy1w-_GWcEl_NZ0LqHaAZ31r057bDulx5acA0O41oQIFaefO9otvaVNXBx
iYsUrANVkTRWB1iIa6Qb8YBnhHD0Uv_sUWeAT6pw1159h3N7MF7BqwRP8bQhN0XkzbqiLPlPGISm_8v2UNmQS7OmFeKfrb4saH3PEY8qsxVMZMX0w0RWMZHaOjQTcPo0j2-j1T7HDUPypHReeLg0wrQ30bXNG6OOs6kUNABA4w2MCtL46Rinqq3Rjmc05t7fdmxyxim-y-2pv0IfnAH-IY3eIwDWMTnr8mfSpjjqnnqESBkVAQ8u6A7velD1uq9lxu8K6qAFFQZQ26OyLTWRMvY4C6cVV2iPEAW1cnnUUkrswMin1U04vjGIs6umnbAylRzDvfi5X7g3SggDncrMn1j3f6-eVMc4Hx2019jTf1ZuxqbA-5d3IYU4mY9LzPKQqtu4sXqyp2QyvNCALZ14P9kc2UTfv4LXMojsFsnSfisIVw_Zlv0LwAtkIO0h5xCoqpfIOiSWKuso_Pdbnuealu9HLvZwDEQUKWNkR5ZVw4qs./download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.27.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.27.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘Geospatial_Coordinates.csv’
#
# Geospatial_Coordina 100%[===================>]   2.82K  --.-KB/s    in 0s
#
# 2019-05-20 19:11:39 (52.2 MB/s) - ‘Geospatial_Coordinates.csv’ saved [2891/2891]

# %%
geo_data = pd.read_csv("Geospatial_Coordinates.csv", delimiter=",")

# %% [markdown]
# Create a pandas data frame with the geospacial data

# %%
neighborhoods = pd.merge(df,geo_data, on='Postal Code')
neighborhoods.head()
# Out:
#   Postal Code           Borough      Neighborhood   Latitude  Longitude
# 0         M3A        North York         Parkwoods  43.753259 -79.329656
# 1         M4A        North York  Victoria Village  43.725882 -79.315572
# 2         M5A  Downtown Toronto      Harbourfront  43.654260 -79.360636
# 3         M5A  Downtown Toronto       Regent Park  43.654260 -79.360636
# 4         M6A        North York  Lawrence Heights  43.718518 -79.464763

# %% [markdown]
# Merge the geospacial data with the previous dataframe

# %% [markdown]
# ## Third part: Explore and cluster the neighborhoods in Toronto

# %% [markdown]
# Load more libaries

# %%
import json # library to handle JSON files
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

# %% [markdown]
# Get the coordinates of Toronto

# %%
address = 'Toronto, TO'

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6523873, -79.3835641.

# %% [markdown]
# Map of Toronto with the neighborhoods

# %%
# create map of New York using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Group rows by neighborhood and take the mean of the frequency of occurrence of each category

# %%
toronto_grouped = neighborhoods.groupby('Neighborhood').mean().reset_index()
toronto_grouped.head()
# Out:
#       Neighborhood   Latitude  Longitude
# 0         Adelaide  43.650571 -79.384568
# 1        Agincourt  43.794200 -79.262029
# 2  Agincourt North  43.815252 -79.284577
# 3   Albion Gardens  43.739416 -79.588437
# 4        Alderwood  43.602414 -79.543484

# %% [markdown]
# Run k-means to cluster the neighborhood into 5 clusters.

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([4, 2, 2, 1, 3, 0, 4, 0, 1, 0], dtype=int32)

# %%
# add clustering labels
toronto_grouped.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = neighborhoods

toronto_merged=toronto_merged.drop(columns='Latitude')
toronto_merged=toronto_merged.drop(columns='Longitude')

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(toronto_grouped.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head()
# Out:
#   Postal Code           Borough      Neighborhood  Cluster Labels   Latitude  \
# 0         M3A        North York         Parkwoods               0  43.753259
# 1         M4A        North York  Victoria Village               2  43.725882
# 2         M5A  Downtown Toronto      Harbourfront               4  43.654260
# 3         M5A  Downtown Toronto       Regent Park               4  43.654260
# 4         M6A        North York  Lawrence Heights               1  43.718518
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.360636
# 4 -79.464763

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_grouped['Latitude'], toronto_grouped['Longitude'], toronto_grouped['Neighborhood'], toronto_grouped['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
